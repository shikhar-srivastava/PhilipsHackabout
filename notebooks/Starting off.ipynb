# %%
import pandas as pd
import numpy as np

# %%
path='../preprocessed/amlodipine.csv'
df=pd.read_csv(path)

# %%
df.head(3)
# Out:
#    Groups  Gender  Age_yrs  Height_cm  Weight_Kgs    BMI  DM  Family_HisCAD  \
# 0       1       1       57        158          66  26.44   0              0
# 1       1       1       65        154          64  26.99   0              0
# 2       1       1       54        150          58  25.78   0              0
#
#    Hyperlipidaemia  Smoking status     ...       Vasopressin   Unnamed: 37  \
# 0                0               0     ...              3.571          NaN
# 1                1               0     ...              5.414          NaN
# 2                0               1     ...              0.793          NaN
#
#    Unnamed: 38  Unnamed: 39  Unnamed: 40  Unnamed: 41  Unnamed: 42  \
# 0          NaN          NaN          NaN          NaN          NaN
# 1          NaN          NaN          NaN          NaN          NaN
# 2          NaN          NaN          NaN          NaN          NaN
#
#    Unnamed: 43  Unnamed: 44  Unnamed: 45
# 0          NaN          NaN          NaN
# ...

# %% [markdown]
# 9 empty datasets

# %%
df = df.dropna(axis=1,how='all')

# %%
df.describe()
# Out:
#            Groups      Gender     Age_yrs   Height_cm  Weight_Kgs         BMI  \
# count  206.000000  206.000000  206.000000  206.000000  206.000000  206.000000
# mean     1.980583    0.553398   57.800971  157.873786   62.207767   24.876748
# std      0.814270    0.498352    9.584754   10.053204   10.179345    2.770028
# min      1.000000    0.000000   31.000000  131.000000   40.000000   13.840000
# 25%      1.000000    0.000000   52.000000  150.000000   56.000000   23.220000
# 50%      2.000000    1.000000   59.000000  156.000000   62.000000   24.650000
# 75%      3.000000    1.000000   66.000000  168.000000   67.750000   26.520000
# max      3.000000    1.000000   70.000000  176.000000   86.000000   31.390000
#
#                DM  Family_HisCAD  Hyperlipidaemia  Smoking status  \
# count  206.000000     206.000000       206.000000      206.000000
# mean     0.490291       0.286408         0.398058        0.266990
# std      0.501124       0.453184         0.490690        0.443465
# ...
